# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="1035890483" href="javascript:toggle_input_1035890483()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1035890483;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1035890483 = document.getElementById("1035890483");
#                 var cell = link_1035890483;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1035890483;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1035890483 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1035890483 = cell.previousElementSibling;
#                 }
#                 input_1035890483.style.display = "none"; // hide
#
#                 toggle_input_1035890483 = function() {
#                     if (input_1035890483.style.display == "none") {
#                         input_1035890483.style.display = ""; // show
#                         link_1035890483.innerHTML = "Hide Input";
#                     } else {
#                         input_1035890483.style.display = "none"; // hide
#                         link_1035890483.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1035890483 = $("a[id='1035890483']");
#                 var cell_1035890483 = link_1035890483.parents("div.cell:first");
#                 if (cell_1035890483.length == 0) {
#                     cell_1035890483 = link_1035890483.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1035890483 = cell_1035890483.children("div.input");
#                 if (input_1035890483.length == 0) {
#                     input_1035890483 = cell_1035890483.prev("div.nbinput");
#                 }
#                 input_1035890483.hide();
#
#                 toggle_input_1035890483 = function() {
#                     if (input_1035890483.is(':hidden')) {
#                         input_1035890483.slideDown();
#                         link_1035890483[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1035890483.slideUp();
#                         link_1035890483[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="487251802" href="javascript:toggle_input_487251802()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_487251802;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_487251802 = document.getElementById("487251802");
#                 var cell = link_487251802;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_487251802;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_487251802 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_487251802 = cell.previousElementSibling;
#                 }
#                 input_487251802.style.display = "none"; // hide
#
#                 toggle_input_487251802 = function() {
#                     if (input_487251802.style.display == "none") {
#                         input_487251802.style.display = ""; // show
#                         link_487251802.innerHTML = "Hide Input";
#                     } else {
#                         input_487251802.style.display = "none"; // hide
#                         link_487251802.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_487251802 = $("a[id='487251802']");
#                 var cell_487251802 = link_487251802.parents("div.cell:first");
#                 if (cell_487251802.length == 0) {
#                     cell_487251802 = link_487251802.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_487251802 = cell_487251802.children("div.input");
#                 if (input_487251802.length == 0) {
#                     input_487251802 = cell_487251802.prev("div.nbinput");
#                 }
#                 input_487251802.hide();
#
#                 toggle_input_487251802 = function() {
#                     if (input_487251802.is(':hidden')) {
#                         input_487251802.slideDown();
#                         link_487251802[0].innerHTML = "Hide Input";
#                     } else {
#                         input_487251802.slideUp();
#                         link_487251802[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")
hide_input()
# Out:
#         <a id="694204949" href="javascript:toggle_input_694204949()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_694204949;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_694204949 = document.getElementById("694204949");
#                 var cell = link_694204949;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_694204949;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_694204949 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_694204949 = cell.previousElementSibling;
#                 }
#                 input_694204949.style.display = "none"; // hide
#
#                 toggle_input_694204949 = function() {
#                     if (input_694204949.style.display == "none") {
#                         input_694204949.style.display = ""; // show
#                         link_694204949.innerHTML = "Hide Input";
#                     } else {
#                         input_694204949.style.display = "none"; // hide
#                         link_694204949.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_694204949 = $("a[id='694204949']");
#                 var cell_694204949 = link_694204949.parents("div.cell:first");
#                 if (cell_694204949.length == 0) {
#                     cell_694204949 = link_694204949.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_694204949 = cell_694204949.children("div.input");
#                 if (input_694204949.length == 0) {
#                     input_694204949 = cell_694204949.prev("div.nbinput");
#                 }
#                 input_694204949.hide();
#
#                 toggle_input_694204949 = function() {
#                     if (input_694204949.is(':hidden')) {
#                         input_694204949.slideDown();
#                         link_694204949[0].innerHTML = "Hide Input";
#                     } else {
#                         input_694204949.slideUp();
#                         link_694204949[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel("Neuron")
ax.set_xlabel("Time (s)")
hide_input()
# Out:
#         <a id="1270431133" href="javascript:toggle_input_1270431133()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1270431133;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1270431133 = document.getElementById("1270431133");
#                 var cell = link_1270431133;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1270431133;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1270431133 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1270431133 = cell.previousElementSibling;
#                 }
#                 input_1270431133.style.display = "none"; // hide
#
#                 toggle_input_1270431133 = function() {
#                     if (input_1270431133.style.display == "none") {
#                         input_1270431133.style.display = ""; // show
#                         link_1270431133.innerHTML = "Hide Input";
#                     } else {
#                         input_1270431133.style.display = "none"; // hide
#                         link_1270431133.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1270431133 = $("a[id='1270431133']");
#                 var cell_1270431133 = link_1270431133.parents("div.cell:first");
#                 if (cell_1270431133.length == 0) {
#                     cell_1270431133 = link_1270431133.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1270431133 = cell_1270431133.children("div.input");
#                 if (input_1270431133.length == 0) {
#                     input_1270431133 = cell_1270431133.prev("div.nbinput");
#                 }
#                 input_1270431133.hide();
#
#                 toggle_input_1270431133 = function() {
#                     if (input_1270431133.is(':hidden')) {
#                         input_1270431133.slideDown();
#                         link_1270431133[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1270431133.slideUp();
#                         link_1270431133[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale), np.arange(A.n_neurons)
)
hide_input()
# Out:
#         <a id="415370097" href="javascript:toggle_input_415370097()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_415370097;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_415370097 = document.getElementById("415370097");
#                 var cell = link_415370097;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_415370097;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_415370097 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_415370097 = cell.previousElementSibling;
#                 }
#                 input_415370097.style.display = "none"; // hide
#
#                 toggle_input_415370097 = function() {
#                     if (input_415370097.style.display == "none") {
#                         input_415370097.style.display = ""; // show
#                         link_415370097.innerHTML = "Hide Input";
#                     } else {
#                         input_415370097.style.display = "none"; // hide
#                         link_415370097.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_415370097 = $("a[id='415370097']");
#                 var cell_415370097 = link_415370097.parents("div.cell:first");
#                 if (cell_415370097.length == 0) {
#                     cell_415370097 = link_415370097.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_415370097 = cell_415370097.children("div.input");
#                 if (input_415370097.length == 0) {
#                     input_415370097 = cell_415370097.prev("div.nbinput");
#                 }
#                 input_415370097.hide();
#
#                 toggle_input_415370097 = function() {
#                     if (input_415370097.is(':hidden')) {
#                         input_415370097.slideDown();
#                         link_415370097[0].innerHTML = "Hide Input";
#                     } else {
#                         input_415370097.slideUp();
#                         link_415370097[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1374070636" href="javascript:toggle_input_1374070636()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1374070636;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1374070636 = document.getElementById("1374070636");
#                 var cell = link_1374070636;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1374070636;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1374070636 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1374070636 = cell.previousElementSibling;
#                 }
#                 input_1374070636.style.display = "none"; // hide
#
#                 toggle_input_1374070636 = function() {
#                     if (input_1374070636.style.display == "none") {
#                         input_1374070636.style.display = ""; // show
#                         link_1374070636.innerHTML = "Hide Input";
#                     } else {
#                         input_1374070636.style.display = "none"; // hide
#                         link_1374070636.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1374070636 = $("a[id='1374070636']");
#                 var cell_1374070636 = link_1374070636.parents("div.cell:first");
#                 if (cell_1374070636.length == 0) {
#                     cell_1374070636 = link_1374070636.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1374070636 = cell_1374070636.children("div.input");
#                 if (input_1374070636.length == 0) {
#                     input_1374070636 = cell_1374070636.prev("div.nbinput");
#                 }
#                 input_1374070636.hide();
#
#                 toggle_input_1374070636 = function() {
#                     if (input_1374070636.is(':hidden')) {
#                         input_1374070636.slideDown();
#                         link_1374070636[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1374070636.slideUp();
#                         link_1374070636[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1522896286" href="javascript:toggle_input_1522896286()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1522896286;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1522896286 = document.getElementById("1522896286");
#                 var cell = link_1522896286;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1522896286;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1522896286 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1522896286 = cell.previousElementSibling;
#                 }
#                 input_1522896286.style.display = "none"; // hide
#
#                 toggle_input_1522896286 = function() {
#                     if (input_1522896286.style.display == "none") {
#                         input_1522896286.style.display = ""; // show
#                         link_1522896286.innerHTML = "Hide Input";
#                     } else {
#                         input_1522896286.style.display = "none"; // hide
#                         link_1522896286.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1522896286 = $("a[id='1522896286']");
#                 var cell_1522896286 = link_1522896286.parents("div.cell:first");
#                 if (cell_1522896286.length == 0) {
#                     cell_1522896286 = link_1522896286.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1522896286 = cell_1522896286.children("div.input");
#                 if (input_1522896286.length == 0) {
#                     input_1522896286 = cell_1522896286.prev("div.nbinput");
#                 }
#                 input_1522896286.hide();
#
#                 toggle_input_1522896286 = function() {
#                     if (input_1522896286.is(':hidden')) {
#                         input_1522896286.slideDown();
#                         link_1522896286[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1522896286.slideUp();
#                         link_1522896286[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1728693203" href="javascript:toggle_input_1728693203()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1728693203;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1728693203 = document.getElementById("1728693203");
#                 var cell = link_1728693203;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1728693203;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1728693203 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1728693203 = cell.previousElementSibling;
#                 }
#                 input_1728693203.style.display = "none"; // hide
#
#                 toggle_input_1728693203 = function() {
#                     if (input_1728693203.style.display == "none") {
#                         input_1728693203.style.display = ""; // show
#                         link_1728693203.innerHTML = "Hide Input";
#                     } else {
#                         input_1728693203.style.display = "none"; // hide
#                         link_1728693203.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1728693203 = $("a[id='1728693203']");
#                 var cell_1728693203 = link_1728693203.parents("div.cell:first");
#                 if (cell_1728693203.length == 0) {
#                     cell_1728693203 = link_1728693203.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1728693203 = cell_1728693203.children("div.input");
#                 if (input_1728693203.length == 0) {
#                     input_1728693203 = cell_1728693203.prev("div.nbinput");
#                 }
#                 input_1728693203.hide();
#
#                 toggle_input_1728693203 = function() {
#                     if (input_1728693203.is(':hidden')) {
#                         input_1728693203.slideDown();
#                         link_1728693203[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1728693203.slideUp();
#                         link_1728693203[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[Asquare_probe], label="Decoded esimate")
plt.plot(sim.trange(), np.square(sim.data[input_probe]), label="Input signal squared")
plt.legend(loc="best", fontsize="medium")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1094536298" href="javascript:toggle_input_1094536298()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1094536298;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1094536298 = document.getElementById("1094536298");
#                 var cell = link_1094536298;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1094536298;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1094536298 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1094536298 = cell.previousElementSibling;
#                 }
#                 input_1094536298.style.display = "none"; // hide
#
#                 toggle_input_1094536298 = function() {
#                     if (input_1094536298.style.display == "none") {
#                         input_1094536298.style.display = ""; // show
#                         link_1094536298.innerHTML = "Hide Input";
#                     } else {
#                         input_1094536298.style.display = "none"; // hide
#                         link_1094536298.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1094536298 = $("a[id='1094536298']");
#                 var cell_1094536298 = link_1094536298.parents("div.cell:first");
#                 if (cell_1094536298.length == 0) {
#                     cell_1094536298 = link_1094536298.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1094536298 = cell_1094536298.children("div.input");
#                 if (input_1094536298.length == 0) {
#                     input_1094536298 = cell_1094536298.prev("div.nbinput");
#                 }
#                 input_1094536298.hide();
#
#                 toggle_input_1094536298 = function() {
#                     if (input_1094536298.is(':hidden')) {
#                         input_1094536298.slideDown();
#                         link_1094536298[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1094536298.slideUp();
#                         link_1094536298[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="692497461" href="javascript:toggle_input_692497461()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_692497461;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_692497461 = document.getElementById("692497461");
#                 var cell = link_692497461;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_692497461;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_692497461 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_692497461 = cell.previousElementSibling;
#                 }
#                 input_692497461.style.display = "none"; // hide
#
#                 toggle_input_692497461 = function() {
#                     if (input_692497461.style.display == "none") {
#                         input_692497461.style.display = ""; // show
#                         link_692497461.innerHTML = "Hide Input";
#                     } else {
#                         input_692497461.style.display = "none"; // hide
#                         link_692497461.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_692497461 = $("a[id='692497461']");
#                 var cell_692497461 = link_692497461.parents("div.cell:first");
#                 if (cell_692497461.length == 0) {
#                     cell_692497461 = link_692497461.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_692497461 = cell_692497461.children("div.input");
#                 if (input_692497461.length == 0) {
#                     input_692497461 = cell_692497461.prev("div.nbinput");
#                 }
#                 input_692497461.hide();
#
#                 toggle_input_692497461 = function() {
#                     if (input_692497461.is(':hidden')) {
#                         input_692497461.slideDown();
#                         link_692497461[0].innerHTML = "Hide Input";
#                     } else {
#                         input_692497461.slideUp();
#                         link_692497461[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1248043012" href="javascript:toggle_input_1248043012()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1248043012;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1248043012 = document.getElementById("1248043012");
#                 var cell = link_1248043012;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1248043012;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1248043012 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1248043012 = cell.previousElementSibling;
#                 }
#                 input_1248043012.style.display = "none"; // hide
#
#                 toggle_input_1248043012 = function() {
#                     if (input_1248043012.style.display == "none") {
#                         input_1248043012.style.display = ""; // show
#                         link_1248043012.innerHTML = "Hide Input";
#                     } else {
#                         input_1248043012.style.display = "none"; // hide
#                         link_1248043012.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1248043012 = $("a[id='1248043012']");
#                 var cell_1248043012 = link_1248043012.parents("div.cell:first");
#                 if (cell_1248043012.length == 0) {
#                     cell_1248043012 = link_1248043012.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1248043012 = cell_1248043012.children("div.input");
#                 if (input_1248043012.length == 0) {
#                     input_1248043012 = cell_1248043012.prev("div.nbinput");
#                 }
#                 input_1248043012.hide();
#
#                 toggle_input_1248043012 = function() {
#                     if (input_1248043012.is(':hidden')) {
#                         input_1248043012.slideDown();
#                         link_1248043012[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1248043012.slideUp();
#                         link_1248043012[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color="k")
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color="k")
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color="k")
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1112903042" href="javascript:toggle_input_1112903042()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1112903042;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1112903042 = document.getElementById("1112903042");
#                 var cell = link_1112903042;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1112903042;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1112903042 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1112903042 = cell.previousElementSibling;
#                 }
#                 input_1112903042.style.display = "none"; // hide
#
#                 toggle_input_1112903042 = function() {
#                     if (input_1112903042.style.display == "none") {
#                         input_1112903042.style.display = ""; // show
#                         link_1112903042.innerHTML = "Hide Input";
#                     } else {
#                         input_1112903042.style.display = "none"; // hide
#                         link_1112903042.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1112903042 = $("a[id='1112903042']");
#                 var cell_1112903042 = link_1112903042.parents("div.cell:first");
#                 if (cell_1112903042.length == 0) {
#                     cell_1112903042 = link_1112903042.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1112903042 = cell_1112903042.children("div.input");
#                 if (input_1112903042.length == 0) {
#                     input_1112903042 = cell_1112903042.prev("div.nbinput");
#                 }
#                 input_1112903042.hide();
#
#                 toggle_input_1112903042 = function() {
#                     if (input_1112903042.is(':hidden')) {
#                         input_1112903042.slideDown();
#                         link_1112903042[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1112903042.slideUp();
#                         link_1112903042[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel("Time (s)")

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
hide_input()
# Out:
#         <a id="460036973" href="javascript:toggle_input_460036973()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_460036973;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_460036973 = document.getElementById("460036973");
#                 var cell = link_460036973;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_460036973;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_460036973 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_460036973 = cell.previousElementSibling;
#                 }
#                 input_460036973.style.display = "none"; // hide
#
#                 toggle_input_460036973 = function() {
#                     if (input_460036973.style.display == "none") {
#                         input_460036973.style.display = ""; // show
#                         link_460036973.innerHTML = "Hide Input";
#                     } else {
#                         input_460036973.style.display = "none"; // hide
#                         link_460036973.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_460036973 = $("a[id='460036973']");
#                 var cell_460036973 = link_460036973.parents("div.cell:first");
#                 if (cell_460036973.length == 0) {
#                     cell_460036973 = link_460036973.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_460036973 = cell_460036973.children("div.input");
#                 if (input_460036973.length == 0) {
#                     input_460036973 = cell_460036973.prev("div.nbinput");
#                 }
#                 input_460036973.hide();
#
#                 toggle_input_460036973 = function() {
#                     if (input_460036973.is(':hidden')) {
#                         input_460036973.slideDown();
#                         link_460036973[0].innerHTML = "Hide Input";
#                     } else {
#                         input_460036973.slideUp();
#                         link_460036973[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
